# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import numpy as np
import feather

# %%
anns = feather.read_dataframe(os.path.join("resources","annotation_df.feather"))

# %%
print(anns.shape)
anns.head()
# Out:
# (6859, 16)
#   annotation_id  calcification  internalstructure  lobulation  malignancy  \
# 0             2              6                  1           1           3
# 1             6              6                  1           2           4
# 2            10              6                  1           4           5
# 3            13              6                  1           2           3
# 4             1              6                  1           1           3
#
#    margin nodule_id  nodule_number      patient_id scan_id  sphericity  \
# 0       4         4            1.0  LIDC-IDRI-0078       1           4
# 1       2     12329            1.0  LIDC-IDRI-0078       1           4
# 2       4     16317            1.0  LIDC-IDRI-0078       1           4
# 3       3      2054            1.0  LIDC-IDRI-0078       1           4
# 4       4         3            2.0  LIDC-IDRI-0078       1           3
#
#    spiculation  sublety  texture patient_number nodule_idx
# 0            2        4        5           0078     007801
# 1            1        4        5           0078     007801
# 2            4        5        5           0078     007801
# 3            2        5        4           0078     007801
# 4            1        5        5           0078     007802

# %%
measure_vars = ["calcification", "internalstructure", "lobulation", "malignancy", "margin", "sphericity", "spiculation", "sublety", "texture"]

# %%
for var in measure_vars:
    print(var)
    print(anns[var].value_counts())
# Out:
# calcification
# 6    6017
# 3     709
# 5      75
# 4      42
# 2      12
# 1       4
# Name: calcification, dtype: int64
# internalstructure
# 1    6819
# 4      27
# 2      11
# 3       1
# 5       1
# Name: internalstructure, dtype: int64
# lobulation
# 1    4117
# 2    1451
# 3     714
# 4     386
# 5     191
# Name: lobulation, dtype: int64
# malignancy
# 3    2606
# 2    1580
# 1    1020
# 4     962
# 5     691
# Name: malignancy, dtype: int64
# margin
# 5    2830
# 4    2149
# 3     896
# 2     620
# 1     364
# Name: margin, dtype: int64
# sphericity
# 4    2316
# 3    2096
# 5    1845
# 2     583
# 1      19
# Name: sphericity, dtype: int64
# spiculation
# 1    4620
# 2    1200
# 3     517
# 4     269
# 5     253
# Name: spiculation, dtype: int64
# sublety
# 5    2542
# 4    1897
# 3    1446
# 2     625
# 1     349
# Name: sublety, dtype: int64
# texture
# 5    5020
# 4     823
# 1     480
# 3     381
# 2     155
# Name: texture, dtype: int64
